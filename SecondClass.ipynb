# %% [markdown]
# Variables

# %%
a=6

# %%
b=5

# %%
print(10)
# Out:
# 10

# %%
print(b)
# Out:
# 5

# %%
print("a")
# Out:
# a

# %%
type(b)
# Out:
# int

# %%
5
# Out:
# 5

# %%
"5"
# Out:
# '5'

# %%
type("5")
# Out:
# str

# %%
type(5.5)
# Out:
# float

# %%
a=5
b="10"
c=6.8

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
type(c)
# Out:
# float

# %%
print(type(a),type(b),type(c))
# Out:
# <class 'int'> <class 'str'> <class 'float'>

# %%
print("i am Ali")
# Out:
# i am Ali

# %%
z=5

# %%
print(z)
# Out:
# 5

# %%
a="this is class of AI batch"
b=1

# %%
print(a,b)
# Out:
# this is class of AI batch 1

# %%
a="this is class of AI batch"
b=" 1"

# %%
print(a+b)
# Out:
# this is class of AI batch 1

# %%
b=4
a=f"this is class of AI batch {b}"

# %%
print(a)
# Out:
# this is class of AI batch 4

# %%
a[0]
# Out:
# 't'

# %%
a[-1]
# Out:
# '4'

# %%
a[1:4]
# Out:
# 'his'

# %%
a[1:2]
# Out:
# 'h'

# %%
a[1:5]
# Out:
# 'his '

# %%
a[1:10:2]
# Out:
# 'hsi l'

# %%
a=5
b=10

# %%
a*b
# Out:
# 50

# %%
a/5
# Out:
# 1.0

# %%
a=2
b=10
b%a
# Out:
# 0

# %%
a=2
b=11
b%a
# Out:
# 1

# %%
a=4
b=15
b%a
# Out:
# 3

# %%
4**2
# Out:
# 16

# %%
ailist=[]
aidic={}
aituple=()

# %%
ailist=[1,"raheem",4.7]

# %%
ailist
# Out:
# [1, 'raheem', 4.7]

# %%
type(ailist)
# Out:
# list

# %%
ailist[0]
# Out:
# 1

# %%
ailist[1]
# Out:
# 'raheem'

# %%
ailist[2]
# Out:
# 4.7

# %%
a="5"

# %%
print(type(int(a)))
# Out:
# <class 'int'>

# %%
a="5"

# %%
type(int(a))
# Out:
# int

# %%
type(str(a))
# Out:
# str

# %%
ailist.append("aiclass")

# %%
ailist
# Out:
# [1, 'raheem', 4.7, 'aiclass']

# %%
ailist.append(1)

# %%
ailist.count(4.7)
# Out:
# 1

# %%
ailist.pop()
# Out:
# 1

# %%
ailist.pop()
# Out:
# 'aiclass'

# %%
ailist.reverse()

# %%
ailist
# Out:
# [4.7, 'raheem', 1]

# %%
aidic={"key":6}

# %%
type(aidic)
# Out:
# dict

# %%
aidic["key"]
# Out:
# 6

# %%
aidic={"a":5,"b":8,6:"raheem"}

# %%
aidic[6]
# Out:
# 'raheem'

# %%
aidic={"a":[1,2,3,4,5,6,7]}

# %%
aidic["a"]
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
print(3)
# Out:
# 3

# %%
ailist=[1,2,3,{"c":5}]

# %%
ailist
# Out:
# [1, 2, 3, {'c': 5}]

# %%
ailist=[1,2,3,{"c":[9,8,7,6]}]

# %%
ailist
# Out:
# [1, 2, 3, {'c': [9, 8, 7, 6]}]

# %%
ailist[2]
# Out:
# 3

# %%
ailist[3]
# Out:
# {'c': [9, 8, 7, 6]}

# %%
ailist[3]["c"]
# Out:
# [9, 8, 7, 6]

# %%
ailist[3]["c"][2]
# Out:
# 7

# %%
aidic={"key":{"ar":[3,4,5,{"az":5}]}}

# %%
aidic["key"]["ar"][3]
# Out:
# {'az': 5}
