# %%
5>6
# Out:
# False

# %%
5<6
# Out:
# True

# %%
a=True

# %%
type(a)
# Out:
# bool

# %%
a=6
b=8

# %%
a,b=6,8

# %%
a!=b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a="this is AI's classes"

# %%
a=["this is AI's classes",3]

# %%
len(a)
# Out:
# 2

# %%
aidic={2:"a",5:"b"}

# %%
aidic
# Out:
# {2: 'a', 5: 'b'}

# %%
aidic.items()
# Out:
# dict_items([(2, 'a'), (5, 'b')])

# %%
aidic.values()
# Out:
# dict_values(['a', 'b'])

# %%
aidic.keys()
# Out:
# dict_keys([2, 5])

# %%
aidic[6]="c"

# %%
aidic
# Out:
# {2: 'c', 5: 'b', 6: 'c'}

# %%
aidic[2] ="c"

# %%
aidic
# Out:
# {2: 'c', 5: 'b', 6: 'c'}

# %%
a =[1,2,3]
b=a
a.append(4)
print(b)
# Out:
# [1, 2, 3, 4]

# %%
a=[1,2,3]
b=a
a=a+[4]
print(b)
# Out:
# [1, 2, 3]

# %%
a=[1,2,3]
print(a*2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a=[1,2,3,4,5,6]
if 1 in a:
  print("found 1")
elif 6 in a:
  print("found 6")
else:
  print("not found")
# Out:
# found 1

# %%
a="raheem"
b="aiclass"
print(a+b)
# Out:
# raheemaiclass

# %%
a="raheem"
b=10
try:
  print(a+b)
except:
    print("there is issue")
# Out:
# there is issue

# %%
#git clone
#git pull
#git push
#commit
